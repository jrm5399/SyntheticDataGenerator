# %% [markdown]
# ## Imports

# %%
#Imports
import cv2
import matplotlib.pyplot as plt
import os
import numpy as np
import albumentations as A
import time
from tqdm import tqdm
from google.colab import drive
import re
from PIL import Image, ImageOps, ImageDraw
from keras.preprocessing.image import ImageDataGenerator
import random
import requests
from io import BytesIO
from bs4 import BeautifulSoup
import urllib
import string
import random

# %% [markdown]
# ## Mounting Google Drive

# %%
#Upload my Files from Google Drive
drive.mount('/content/gdrive')

#extract and unzip folder
# !unzip "gdrive/MyDrive/Synthetic-Data/images.zip"
# Out:
# Mounted at /content/gdrive
# Archive:  gdrive/MyDrive/Synthetic-Data/images.zip
#    creating: images/
#   inflating: images/.DS_Store
#   inflating: __MACOSX/images/._.DS_Store
#    creating: images/bg/
#    creating: images/real_pics/
#   inflating: images/bg/pawel-czerwinski-vI5XwPbGvmY-unsplash.jpeg
#   inflating: __MACOSX/images/bg/._pawel-czerwinski-vI5XwPbGvmY-unsplash.jpeg
#   inflating: images/bg/.DS_Store
#   inflating: __MACOSX/images/bg/._.DS_Store
#   inflating: images/bg/photo-1553095066-5014bc7b7f2d.jpeg
#   inflating: __MACOSX/images/bg/._photo-1553095066-5014bc7b7f2d.jpeg
#   inflating: images/bg/fi1.jpeg
#   inflating: __MACOSX/images/bg/._fi1.jpeg
#   inflating: images/bg/tlC9Xd.jpeg
#   inflating: __MACOSX/images/bg/._tlC9Xd.jpeg
#   inflating: images/bg/abstract-natural-backgrounds-your-design-51859129.jpeg
#   inflating: __MACOSX/images/bg/._abstract-natural-backgrounds-your-design-51859129.jpeg
#   inflating: images/bg/pexels-eberhard-grossgasteiger-1287142.jpeg
#   inflating: __MACOSX/images/bg/._pexels-eberhard-grossgasteiger-1287142.jpeg
#   inflating: images/bg/1.magebyRodionKutsaevviaUnsplash.jpeg
#   inflating: __MACOSX/images/bg/._1.magebyRodionKutsaevviaUnsplash.jpeg
#   inflating: images/bg/landscape-nature-view-background-view-window-landscape-nature-view-background-view-window-wonderful-landscape-121459679.jpeg
#   inflating: __MACOSX/images/bg/._landscape-nature-view-background-view-window-landscape-nature-view-background-view-window-wonderful-landscape-121459679.jpeg
#   inflating: images/bg/360_F_577086456_XVFdlsSKspwN3EkZ0pqnuwe1ok7RAFTd.jpeg
#   inflating: __MACOSX/images/bg/._360_F_577086456_XVFdlsSKspwN3EkZ0pqnuwe1ok7RAFTd.jpeg
#   inflating: images/bg/Miami_Zoom-Rooms-Customized-Background-Images_Downtown_10-1440x900.jpeg
#   inflating: __MACOSX/images/bg/._Miami_Zoom-Rooms-Customized-Background-Images_Downtown_10-1440x900.jpeg
#   inflating: images/bg/panorama-view-sea-colorful-sky-cloud-bright-full-moon-seascape-to-night-serenity-nature-background-outdoor-131503361.jpeg
#   inflating: __MACOSX/images/bg/._panorama-view-sea-colorful-sky-cloud-bright-full-moon-seascape-to-night-serenity-nature-background-outdoor-131503361.jpeg
#   inflating: images/bg/pexels-stein-egil-liland-1933239.jpeg
#   inflating: __MACOSX/images/bg/._pexels-stein-egil-liland-1933239.jpeg
#   inflating: images/real_pics/Golgi.png
#   inflating: __MACOSX/images/real_pics/._Golgi.png
#   inflating: images/real_pics/.DS_Store
#   inflating: __MACOSX/images/real_pics/._.DS_Store
#   inflating: images/real_pics/Centriole.png
#   inflating: __MACOSX/images/real_pics/._Centriole.png
#   inflating: images/real_pics/Vessicle.png
#   inflating: __MACOSX/images/real_pics/._Vessicle.png
#   inflating: images/real_pics/Mitochondria.png
#   inflating: __MACOSX/images/real_pics/._Mitochondria.png
#   inflating: images/real_pics/RoughER.png
#   inflating: __MACOSX/images/real_pics/._RoughER.png
#   inflating: images/real_pics/SmoothER.png
#   inflating: __MACOSX/images/real_pics/._SmoothER.png
#   inflating: images/real_pics/Nucleus.png
#   inflating: __MACOSX/images/real_pics/._Nucleus.png
#   inflating: images/real_pics/Lysosome.png
#   inflating: __MACOSX/images/real_pics/._Lysosome.png

# %% [markdown]
# ## Functions

# %%
def masking(img):
  mask = img.getchannel('A')
  return (img, mask)


def Data_Augmentation(path, img, i):
    # convert to numpy array
    img = Image.open(path + img)
    data = np.asarray(img)
    # expand dimension to one sample
    samples = np.expand_dims(data, 0)
    # create image data augmentation generator
    datagen = ImageDataGenerator(
        rotation_range=180,       # random rotation augmentation
        brightness_range=[0.1,2.5],  # random brightness augmentation
        zoom_range=[0.4,2.1]     # random zoom augmentation
    )
    # prepare iterator
    it = datagen.flow(samples, batch_size=1)
    # generate an augmented image
    augmented_data = it.next()[0].astype('uint8')
    # crop the image to ensure the object is always within the screenshot
    h, w, _ = augmented_data.shape
    if h > w:
        pad = int((h - w) / 2)
        augmented_data = augmented_data[pad:pad+w, :]
    elif w > h:
        pad = int((w - h) / 2)
        augmented_data = augmented_data[:, pad:pad+h]
    # convert numpy array to PIL Image object
    augmented_img = Image.fromarray(augmented_data)
    # return the augmented image as a PIL Image object
    #return augmented_img

    folder_path = "augmented_data"
    pic_name = os.path.splitext(pic)[0]
    #image_folder_path = os.path.join(folder_path, "images")
    # Save the image data to a file
    os.makedirs(folder_path, exist_ok=True)
    with open(f"{folder_path}/{pic_name}_{count}.png", "wb") as f:
        augmented_img.save(f, format='PNG')

def append_to_bg(bg, img, obj_names):
    #open images
    img_str = img
    bg = Image.open("images/bg/" + bg)
    img = Image.open("augmented_data/"+img)

    # Get the size of the background image
    bg_width, bg_height = bg.size

    # Resize the image to paste to fit within the background image
    img = img.resize((int(bg_width/2), int(bg_height/2)))

    # Generate a random location for the good image
    offset_x = random.randint(0, bg_width - img.width)
    offset_y = random.randint(0, bg_height - img.height)

    # Get the alpha channel of the image to paste
    mask = img.getchannel('A')

    # Paste the image onto the background using the alpha channel as the mask
    bg.paste(img, (offset_x, offset_y), mask)

    #convert to np array
    np_image = np.asarray(img)

    # Get the bounding box coordinates
    mask = np.array(img.convert('L'))
    xmin, ymin, xmax, ymax = BBox(mask)


    # draw the bounding box on the image
    #color = (0, 255, 0) # green color
    #thickness = 2
    #img_with_bbox = cv2.rectangle(np_image, (xmin, ymin), (xmax, ymax), color, thickness)
    #draw = ImageDraw.Draw(bg)
    #draw.rectangle((offset_x + xmin, offset_y + ymin, offset_x + xmax, offset_y + ymax), outline=(0, 255, 0), width=2)


    name, ext = os.path.splitext(img_str)
    image_name = name.split("_")[0]


    # Convert bounding box coordinates to YOLOv5 format
    center_x = (offset_x + img.width/2) / bg_width
    center_y = (offset_y + img.height/2) / bg_height
    width = img.width / bg_width
    height = img.height / bg_height

    yolo_bbox = [obj_names[image_name], center_x, center_y, width, height]
    #return (bg,yolo_bbox)


    #write to final_data folder
    rand_name = ''.join(random.choices(string.ascii_letters + string.digits, k=6))

    # Save the image data to a file
    with open(f"final_data/images/{rand_name}.png", "wb") as f:
      bg.save(f)

    with open(f"final_data/yolo/{rand_name}.txt", "wb") as f:
      bboxes = " ".join(str(num) for num in yolo_bbox).encode("utf-8")
      f.write(bboxes)





def webscrape(url, folder_path):
  # Create the directory if it doesn't exist
  os.makedirs(folder_path, exist_ok=True)

  # Make a GET request to the URL
  response = requests.get(url)

  # Use BeautifulSoup to parse the HTML content of the response
  soup = BeautifulSoup(response.content, "html.parser")

  # Find all the <img> tags in the HTML
  image_tags = soup.find_all("img")

  # Extract the URLs of the images
  image_urls = [img["src"] for img in image_tags]

  # Download the images and save them locally
  for i, url in enumerate(image_urls):
    try:
      rand_name = ''.join(random.choices(string.ascii_letters + string.digits, k=6))
      # Open a connection to the URL and read the image data
      response = requests.get(url)
      image_data = response.content

      # Save the image data to a file
      with open(f"{folder_path}/{rand_name}.png", "wb") as f:
          f.write(image_data)
          
    except Exception as e:
      # Print a message for any image that couldn't be downloaded
      print(f"Error downloading image {i}: {e}")


def BBox(image_arr):
  # Threshold the image to obtain a binary mask
  _, mask = cv2.threshold(image_arr, 0, 255, cv2.THRESH_BINARY)

  # Find the contours in the binary mask
  contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

  # Get the bounding box of the largest contour
  if len(contours) > 0:
      largest_contour = max(contours, key=cv2.contourArea)
      x, y, w, h = cv2.boundingRect(largest_contour)
      return x, y, x+w, y+h

  # If no contours are found, return None
  return None

# %% [markdown]
# ## Path To Files

# %%
#Path to Files
PATH_real_pics = 'images/real_pics'
PATH_bg = 'images/bg'


#Grab the Images
real_pics, bg = [], []

#Picture Paths
real_path = PATH_real_pics + '/'
bg_path = PATH_bg + '/'

# %% [markdown]
# ## Mapping of object names to values

# %%
obj_names = {
    0: "Centriole",
    1: "Golgi",
    2: "Lysosome",
    3: "Mitochondria",
    4: "Nucleus",
    5: "RoughER",
    6: "SmoothER",
    7: "Vessicle"
}
# Reverse the obj_names dictionary
obj_names = {v: k for k, v in obj_names.items()}

# %% [markdown]
# ## Converting BG sizes / Web Scrapping

# %%
#Web Scrapping for random backgrounds
bg_urls = [
    "https://unsplash.com/s/photos/random",
    "https://unsplash.com/t/textures-patterns",
    "https://unsplash.com/t/travel",
    "https://unsplash.com/t/animals",
    'https://unsplash.com/t/film'
]
for url in bg_urls:
  webscrape(url, PATH_bg)

# %%
# Loop over the image files in the directory
for pic in os.listdir(PATH_bg):
    try:
        # Open the image file and resize it
        img = Image.open(bg_path + pic)
        img = img.resize((1920, 1080))

         # Save the image data to a file
        with open(f"images/bg/{os.path.basename(bg_path+pic)}", "wb") as f:
          img.save(f)

    except Exception as e:
        # Print an error message for any image that couldn't be opened
        print(f"Error opening image file {pic}: {e}")
# Out:
# Error opening image file kcrAWL.png: cannot identify image file 'images/bg/kcrAWL.png'
# Error opening image file JfAAq7.png: cannot identify image file 'images/bg/JfAAq7.png'
# Error opening image file 7hpMpk.png: cannot identify image file 'images/bg/7hpMpk.png'
# Error opening image file yaD5O1.png: cannot identify image file 'images/bg/yaD5O1.png'
# Error opening image file iRxWQO.png: cannot identify image file 'images/bg/iRxWQO.png'
# Error opening image file yMnzCY.png: cannot identify image file 'images/bg/yMnzCY.png'
# Error opening image file So2Jgb.png: cannot identify image file 'images/bg/So2Jgb.png'
# Error opening image file AZb9Uk.png: cannot identify image file 'images/bg/AZb9Uk.png'
# Error opening image file .DS_Store: cannot identify image file 'images/bg/.DS_Store'
# Error opening image file jqwjDB.png: cannot identify image file 'images/bg/jqwjDB.png'
# Error opening image file mylhYZ.png: cannot identify image file 'images/bg/mylhYZ.png'
# Error opening image file cegrdx.png: cannot identify image file 'images/bg/cegrdx.png'
# Error opening image file WqLIX0.png: cannot identify image file 'images/bg/WqLIX0.png'
# Error opening image file ikhhab.png: cannot identify image file 'images/bg/ikhhab.png'
# Error opening image file Df3d1E.png: cannot identify image file 'images/bg/Df3d1E.png'
# Error opening image file ahJSRB.png: cannot identify image file 'images/bg/ahJSRB.png'

# %%
file_list = os.listdir(PATH_bg)
num_files = len(file_list)
print("Number of files in folder:", num_files)
# Out:
# Number of files in folder: 545

# %% [markdown]
# ## Gathering Data

# %%
# for pic in os.listdir(PATH_real_pics):
#   real_pics.append(pic)


# real_pics.sort()
# real_pics = real_pics[1:]

# %%
# print(real_pics)

# %% [markdown]
# ## Data Augmentation & Masking

# %%
#augmenting images randomly
#real_dataset = []

#how many augmented images per picture : (8xN) = Total
N = 68 #images per item (N items per object to detect)

#for pic in real_pics:
for pic in os.listdir(PATH_real_pics):
  count = 0
  if pic !=".DS_Store":
    #generate N unique images for each pic
    for i in range(N):
      #Augment the picture
      Data_Augmentation(real_path, pic, count)
      count += 1

# %%
file_list = os.listdir("augmented_data/")
num_files = len(file_list)
print("Number of files in folder:", num_files)
# Out:
# Number of files in folder: 544

# %% [markdown]
# # Add new images to background

# %%
os.makedirs("final_data")
os.makedirs("final_data/images")
os.makedirs("final_data/yolo")

# %%
#final_data = []
count = 0

for aug, bg in zip(os.listdir("augmented_data/"), os.listdir(PATH_bg)):
  # final_data.append(append_to_bg(rand_bg, pic, names[j]))
  # try:
  #   append_to_bg(bg, aug)
  # except:
  #   print(f"cant do {aug}/{bg}")
  try:
    append_to_bg(bg, aug, obj_names)
  except:
    print(f"error{pic}")
# Out:
# errorSmoothER.png
# errorSmoothER.png
# errorSmoothER.png
# errorSmoothER.png
# errorSmoothER.png
# errorSmoothER.png
# errorSmoothER.png
# errorSmoothER.png
# errorSmoothER.png
# errorSmoothER.png
# errorSmoothER.png
# errorSmoothER.png
# errorSmoothER.png
# errorSmoothER.png
# errorSmoothER.png
# errorSmoothER.png
# errorSmoothER.png
# errorSmoothER.png
# errorSmoothER.png
# errorSmoothER.png
# errorSmoothER.png

# %% [markdown]
# # Download Data

# %%
# !zip -r final_data.zip final_data/
from google.colab import files
files.download('final_data.zip')
# Out:
#   adding: final_data/ (stored 0%)
#   adding: final_data/yolo/ (stored 0%)
#   adding: final_data/yolo/LcozN2.txt (deflated 42%)
#   adding: final_data/yolo/WR19c4.txt (deflated 40%)
#   adding: final_data/yolo/MYF0rm.txt (deflated 29%)
#   adding: final_data/yolo/yLTQsz.txt (deflated 43%)
#   adding: final_data/yolo/zDBgLP.txt (deflated 43%)
#   adding: final_data/yolo/8FScev.txt (deflated 44%)
#   adding: final_data/yolo/hPwsmN.txt (deflated 44%)
#   adding: final_data/yolo/wbMFQu.txt (deflated 52%)
#   adding: final_data/yolo/ow140l.txt (deflated 45%)
#   adding: final_data/yolo/yG2pzM.txt (deflated 44%)
#   adding: final_data/yolo/ps0pen.txt (deflated 48%)
#   adding: final_data/yolo/QNqLAq.txt (deflated 36%)
#   adding: final_data/yolo/TVUz2Y.txt (deflated 38%)
#   adding: final_data/yolo/gD5Z9E.txt (deflated 34%)
#   adding: final_data/yolo/EEyPaI.txt (deflated 45%)
#   adding: final_data/yolo/CJfNuj.txt (deflated 38%)
#   adding: final_data/yolo/2ttFs5.txt (deflated 49%)
#   adding: final_data/yolo/xWHzRo.txt (deflated 43%)
#   adding: final_data/yolo/BzXnpL.txt (deflated 36%)
#   adding: final_data/yolo/eIkrgY.txt (deflated 46%)
#   adding: final_data/yolo/D875mz.txt (deflated 32%)
#   adding: final_data/yolo/hiBhzR.txt (deflated 20%)
#   adding: final_data/yolo/H9uhwR.txt (deflated 47%)
#   adding: final_data/yolo/aurnfm.txt (deflated 42%)
#   adding: final_data/yolo/FP4YlI.txt (deflated 38%)
#   adding: final_data/yolo/Akg4LX.txt (deflated 31%)
#   adding: final_data/yolo/FkHGnV.txt (deflated 52%)
#   adding: final_data/yolo/H70Byr.txt (deflated 46%)
#   adding: final_data/yolo/RHPPYo.txt (deflated 46%)
#   adding: final_data/yolo/Z68291.txt (deflated 38%)
#   adding: final_data/yolo/0dnHXr.txt (deflated 43%)
#   adding: final_data/yolo/rYuSAe.txt (deflated 35%)
#   adding: final_data/yolo/5cib6m.txt (deflated 43%)
#   adding: final_data/yolo/oS3dpY.txt (deflated 35%)
#   adding: final_data/yolo/s14SEL.txt (deflated 32%)
#   adding: final_data/yolo/Gow60O.txt (deflated 29%)
#   adding: final_data/yolo/3W3Dq5.txt (deflated 37%)
#   adding: final_data/yolo/aeKTRl.txt (deflated 34%)
#   adding: final_data/yolo/MhUUFc.txt (deflated 55%)
#   adding: final_data/yolo/6vTgVO.txt (deflated 39%)
#   adding: final_data/yolo/Z7ulx6.txt (deflated 26%)
#   adding: final_data/yolo/Kzf6bG.txt (deflated 38%)
#   adding: final_data/yolo/QrCKE8.txt (deflated 53%)
#   adding: final_data/yolo/SZkDf3.txt (deflated 37%)
#   adding: final_data/yolo/3S8Ki0.txt (deflated 43%)
#   adding: final_data/yolo/EZLJdw.txt (deflated 38%)
#   adding: final_data/yolo/KVlPe1.txt (deflated 37%)
#   adding: final_data/yolo/EZvlUE.txt (deflated 29%)
#   adding: final_data/yolo/uVc2DK.txt (deflated 42%)
#   adding: final_data/yolo/Sp8T3N.txt (deflated 40%)
#   adding: final_data/yolo/9DV5Ow.txt (deflated 43%)
#   adding: final_data/yolo/TlUgmq.txt (deflated 44%)
#   adding: final_data/yolo/nPvToI.txt (deflated 42%)
#   adding: final_data/yolo/e6oFyb.txt (deflated 38%)
#   adding: final_data/yolo/jRIaFl.txt (deflated 38%)
#   adding: final_data/yolo/DW4xxJ.txt (deflated 39%)
#   adding: final_data/yolo/WOFr38.txt (deflated 42%)
#   adding: final_data/yolo/vfYdiB.txt (deflated 41%)
#   adding: final_data/yolo/sUQbCS.txt (deflated 45%)
#   adding: final_data/yolo/sJwcA7.txt (deflated 41%)
#   adding: final_data/yolo/jSPMmq.txt (deflated 49%)
#   adding: final_data/yolo/l8xlgx.txt (deflated 38%)
#   adding: final_data/yolo/V7RF9T.txt (deflated 34%)
#   adding: final_data/yolo/uuJkdW.txt (deflated 40%)
#   adding: final_data/yolo/zCeBqm.txt (deflated 32%)
#   adding: final_data/yolo/sCh9SP.txt (deflated 42%)
#   adding: final_data/yolo/n6gin8.txt (deflated 42%)
#   adding: final_data/yolo/o9dI4s.txt (deflated 43%)
#   adding: final_data/yolo/bZPF8w.txt (deflated 45%)
#   adding: final_data/yolo/yewB79.txt (deflated 43%)
#   adding: final_data/yolo/hSmT3b.txt (deflated 43%)
#   adding: final_data/yolo/Q2P4Mu.txt (deflated 38%)
#   adding: final_data/yolo/TJ88mT.txt (deflated 41%)
#   adding: final_data/yolo/rmQX3A.txt (deflated 33%)
#   adding: final_data/yolo/TYhhZi.txt (deflated 51%)
#   adding: final_data/yolo/n8A3z9.txt (deflated 47%)
#   adding: final_data/yolo/EOcQKu.txt (deflated 33%)
#   adding: final_data/yolo/7qS2c6.txt (deflated 37%)
#   adding: final_data/yolo/PS8VO9.txt (deflated 29%)
#   adding: final_data/yolo/IXUOye.txt (deflated 45%)
#   adding: final_data/yolo/EA4Szk.txt (deflated 38%)
#   adding: final_data/yolo/u6FC99.txt (deflated 45%)
#   adding: final_data/yolo/hDttQl.txt (deflated 53%)
#   adding: final_data/yolo/VxUUWs.txt (deflated 46%)
#   adding: final_data/yolo/MefaJp.txt (deflated 44%)
#   adding: final_data/yolo/5OKsRj.txt (deflated 49%)
#   adding: final_data/yolo/jihrvA.txt (deflated 38%)
#   adding: final_data/yolo/JTkZdL.txt (deflated 42%)
#   adding: final_data/yolo/SZHJsn.txt (deflated 41%)
#   adding: final_data/yolo/16hDUB.txt (deflated 40%)
#   adding: final_data/yolo/1yup5t.txt (deflated 38%)
#   adding: final_data/yolo/yTtG6x.txt (deflated 46%)
#   adding: final_data/yolo/PQYgDa.txt (deflated 40%)
#   adding: final_data/yolo/N54M99.txt (deflated 40%)
#   adding: final_data/yolo/fg0O0S.txt (deflated 47%)
#   adding: final_data/yolo/7gMyYO.txt (deflated 26%)
#   adding: final_data/yolo/TFyqeg.txt (deflated 52%)
#   adding: final_data/yolo/5J4T7N.txt (deflated 38%)
#   adding: final_data/yolo/pbtm9v.txt (deflated 34%)
#   adding: final_data/yolo/3NBdBz.txt (deflated 38%)
#   adding: final_data/yolo/9L7zbE.txt (deflated 32%)
#   adding: final_data/yolo/UOV7h2.txt (deflated 40%)
#   adding: final_data/yolo/ZOguNK.txt (deflated 47%)
#   adding: final_data/yolo/5OF3jR.txt (deflated 45%)
#   adding: final_data/yolo/qYeMDt.txt (deflated 29%)
#   adding: final_data/yolo/iqoknG.txt (deflated 44%)
#   adding: final_data/yolo/xri621.txt (deflated 42%)
#   adding: final_data/yolo/49VNCb.txt (deflated 39%)
#   adding: final_data/yolo/3VOUJU.txt (deflated 38%)
#   adding: final_data/yolo/vVIKIN.txt (deflated 38%)
#   adding: final_data/yolo/0vrDd3.txt (deflated 33%)
#   adding: final_data/yolo/pFfCrq.txt (deflated 45%)
#   adding: final_data/yolo/JpaFuW.txt (deflated 52%)
#   adding: final_data/yolo/ehMcf0.txt (deflated 40%)
#   adding: final_data/yolo/BT37On.txt (deflated 40%)
#   adding: final_data/yolo/xnpPnK.txt (deflated 34%)
#   adding: final_data/yolo/wgA9UU.txt (deflated 42%)
#   adding: final_data/yolo/uermgn.txt (deflated 35%)
#   adding: final_data/yolo/2EFHvT.txt (deflated 36%)
#   adding: final_data/yolo/jIVj2q.txt (deflated 40%)
#   adding: final_data/yolo/z66Bn8.txt (deflated 44%)
#   adding: final_data/yolo/eIyHNR.txt (deflated 48%)
#   adding: final_data/yolo/SHYB7q.txt (deflated 27%)
#   adding: final_data/yolo/OetKcL.txt (deflated 35%)
#   adding: final_data/yolo/2kxu20.txt (deflated 42%)
#   adding: final_data/yolo/LT7rPq.txt (deflated 34%)
#   adding: final_data/yolo/jzadhr.txt (deflated 44%)
#   adding: final_data/yolo/devjb8.txt (deflated 37%)
#   adding: final_data/yolo/E7okPu.txt (deflated 38%)
#   adding: final_data/yolo/U7oA4D.txt (deflated 42%)
#   adding: final_data/yolo/oAozrp.txt (deflated 30%)
#   adding: final_data/yolo/2UpAhL.txt (deflated 45%)
#   adding: final_data/yolo/AnE1wW.txt (deflated 21%)
#   adding: final_data/yolo/5fW3dl.txt (deflated 29%)
#   adding: final_data/yolo/8ud2cB.txt (deflated 40%)
#   adding: final_data/yolo/pVlH8o.txt (deflated 37%)
#   adding: final_data/yolo/ZJ2MBt.txt (deflated 40%)
#   adding: final_data/yolo/CRJ1wL.txt (deflated 30%)
#   adding: final_data/yolo/XFV7ia.txt (deflated 44%)
#   adding: final_data/yolo/1jNDT0.txt (deflated 44%)
#   adding: final_data/yolo/s1GHot.txt (deflated 40%)
#   adding: final_data/yolo/qSGM5L.txt (deflated 43%)
#   adding: final_data/yolo/635hxC.txt (deflated 44%)
#   adding: final_data/yolo/bCvGel.txt (deflated 49%)
#   adding: final_data/yolo/NfoWRy.txt (deflated 38%)
#   adding: final_data/yolo/chTwht.txt (deflated 52%)
#   adding: final_data/yolo/oUpo0b.txt (deflated 34%)
#   adding: final_data/yolo/elp3OO.txt (deflated 30%)
#   adding: final_data/yolo/2qjnkx.txt (deflated 40%)
#   adding: final_data/yolo/1gEVOB.txt (deflated 38%)
#   adding: final_data/yolo/N7Jxv4.txt (deflated 38%)
#   adding: final_data/yolo/LEvTcZ.txt (deflated 47%)
#   adding: final_data/yolo/vHShUq.txt (deflated 38%)
#   adding: final_data/yolo/5nhIQD.txt (deflated 42%)
#   adding: final_data/yolo/L579qK.txt (deflated 36%)
#   adding: final_data/yolo/phKQW4.txt (deflated 50%)
#   adding: final_data/yolo/NnFqC0.txt (deflated 44%)
#   adding: final_data/yolo/WXfTlS.txt (deflated 41%)
#   adding: final_data/yolo/VyQPXn.txt (deflated 32%)
#   adding: final_data/yolo/6vgQg0.txt (deflated 34%)
#   adding: final_data/yolo/Pnsyl4.txt (deflated 43%)
#   adding: final_data/yolo/lEQvj6.txt (deflated 62%)
#   adding: final_data/yolo/VGca8q.txt (deflated 40%)
#   adding: final_data/yolo/af2QEl.txt (deflated 33%)
#   adding: final_data/yolo/4fyknx.txt (deflated 40%)
#   adding: final_data/yolo/TIeUTf.txt (deflated 43%)
#   adding: final_data/yolo/rFS2Pl.txt (deflated 31%)
#   adding: final_data/yolo/GSVhvM.txt (deflated 43%)
#   adding: final_data/yolo/P9SCL7.txt (deflated 41%)
#   adding: final_data/yolo/bzhb3V.txt (deflated 45%)
#   adding: final_data/yolo/4IkYjp.txt (deflated 40%)
#   adding: final_data/yolo/ENDtIt.txt (deflated 36%)
#   adding: final_data/yolo/hKIsbz.txt (deflated 31%)
#   adding: final_data/yolo/GumLrv.txt (deflated 43%)
#   adding: final_data/yolo/MAFWtO.txt (deflated 47%)
#   adding: final_data/yolo/QR80po.txt (deflated 43%)
#   adding: final_data/yolo/dshKbW.txt (deflated 31%)
#   adding: final_data/yolo/UbFGnp.txt (deflated 39%)
#   adding: final_data/yolo/HgfsDy.txt (deflated 43%)
#   adding: final_data/yolo/NnIL90.txt (deflated 37%)
#   adding: final_data/yolo/2QhALF.txt (deflated 38%)
#   adding: final_data/yolo/e6ySPb.txt (deflated 44%)
#   adding: final_data/yolo/AAQZsy.txt (deflated 38%)
#   adding: final_data/yolo/6pXvXS.txt (deflated 45%)
#   adding: final_data/yolo/ke6ur9.txt (deflated 40%)
#   adding: final_data/yolo/kGubU1.txt (deflated 37%)
#   adding: final_data/yolo/2OZFNQ.txt (deflated 38%)
#   adding: final_data/yolo/NYi8FB.txt (deflated 36%)
#   adding: final_data/yolo/94AV36.txt (deflated 40%)
#   adding: final_data/yolo/OwtA06.txt (deflated 52%)
#   adding: final_data/yolo/9Xcy8m.txt (deflated 39%)
#   adding: final_data/yolo/bAnm6T.txt (deflated 37%)
#   adding: final_data/yolo/KPzNIV.txt (deflated 38%)
#   adding: final_data/yolo/YRpKwV.txt (deflated 53%)
#   adding: final_data/yolo/jFWe66.txt (deflated 34%)
#   adding: final_data/yolo/XF8KRX.txt (deflated 47%)
#   adding: final_data/yolo/N4SiPc.txt (deflated 42%)
#   adding: final_data/yolo/eLzcMk.txt (deflated 39%)
#   adding: final_data/yolo/mNvlOr.txt (deflated 40%)
#   adding: final_data/yolo/ggu3D6.txt (deflated 38%)
#   adding: final_data/yolo/Jtcb5I.txt (deflated 40%)
#   adding: final_data/yolo/My2ZzY.txt (deflated 42%)
#   adding: final_data/yolo/kuXwgY.txt (deflated 32%)
#   adding: final_data/yolo/PhZv5C.txt (deflated 35%)
#   adding: final_data/yolo/WKyyEq.txt (deflated 38%)
#   adding: final_data/yolo/7CsTwH.txt (deflated 18%)
#   adding: final_data/yolo/Ftn3kU.txt (deflated 50%)
#   adding: final_data/yolo/C1eKxM.txt (deflated 40%)
#   adding: final_data/yolo/5bxxLd.txt (deflated 48%)
#   adding: final_data/yolo/ymvEDt.txt (deflated 42%)
#   adding: final_data/yolo/EJlBXj.txt (deflated 35%)
#   adding: final_data/yolo/ur1zpS.txt (deflated 45%)
#   adding: final_data/yolo/KZfWl6.txt (deflated 42%)
#   adding: final_data/yolo/xvdEEe.txt (deflated 42%)
#   adding: final_data/yolo/l3wBkM.txt (deflated 42%)
#   adding: final_data/yolo/oAhbEX.txt (deflated 27%)
#   adding: final_data/yolo/boikB0.txt (deflated 32%)
#   adding: final_data/yolo/1bc1JE.txt (deflated 40%)
#   adding: final_data/yolo/QCWsnv.txt (deflated 37%)
#   adding: final_data/yolo/wM1UTm.txt (deflated 34%)
#   adding: final_data/yolo/w4yDrA.txt (deflated 53%)
#   adding: final_data/yolo/YjC1jg.txt (deflated 34%)
#   adding: final_data/yolo/N6goUh.txt (deflated 40%)
#   adding: final_data/yolo/Ybp3Zi.txt (deflated 34%)
#   adding: final_data/yolo/OlXrRR.txt (deflated 49%)
#   adding: final_data/yolo/GZaX0X.txt (deflated 50%)
#   adding: final_data/yolo/FPm5Co.txt (deflated 38%)
#   adding: final_data/yolo/Nvi9L1.txt (deflated 43%)
#   adding: final_data/yolo/PaesbE.txt (deflated 58%)
#   adding: final_data/yolo/KOOx4W.txt (deflated 41%)
#   adding: final_data/yolo/WxorIF.txt (deflated 38%)
#   adding: final_data/yolo/IwdAvd.txt (deflated 40%)
#   adding: final_data/yolo/RRwyEd.txt (deflated 45%)
#   adding: final_data/yolo/JTK8o5.txt (deflated 44%)
#   adding: final_data/yolo/g5Kccj.txt (deflated 39%)
#   adding: final_data/yolo/lZFGl1.txt (deflated 40%)
#   adding: final_data/yolo/DfpU0H.txt (deflated 38%)
#   adding: final_data/yolo/VFuVDd.txt (deflated 33%)
#   adding: final_data/yolo/tL3iOD.txt (deflated 39%)
#   adding: final_data/yolo/Dz9kje.txt (deflated 20%)
#   adding: final_data/yolo/4hzoQi.txt (deflated 49%)
#   adding: final_data/yolo/WdwS3l.txt (deflated 43%)
#   adding: final_data/yolo/Kcer25.txt (deflated 40%)
#   adding: final_data/yolo/qrDddi.txt (deflated 38%)
#   adding: final_data/yolo/Z2oI2f.txt (deflated 45%)
#   adding: final_data/yolo/nKJoba.txt (deflated 38%)
#   adding: final_data/yolo/Oqfy4Q.txt (deflated 48%)
#   adding: final_data/yolo/vWgrNt.txt (deflated 31%)
#   adding: final_data/yolo/dSFeVN.txt (deflated 40%)
#   adding: final_data/yolo/HOLHuO.txt (deflated 45%)
#   adding: final_data/yolo/W5CTpj.txt (deflated 44%)
#   adding: final_data/yolo/yMIkC6.txt (deflated 40%)
#   adding: final_data/yolo/tNiGh1.txt (deflated 27%)
#   adding: final_data/yolo/eF6CJk.txt (deflated 44%)
#   adding: final_data/yolo/FnWrhr.txt (deflated 37%)
#   adding: final_data/yolo/tds2AM.txt (deflated 40%)
#   adding: final_data/yolo/IedUfS.txt (deflated 41%)
#   adding: final_data/yolo/onjyZ3.txt (deflated 38%)
#   adding: final_data/yolo/4GxaZ4.txt (deflated 34%)
#   adding: final_data/yolo/g0W1Qc.txt (deflated 32%)
#   adding: final_data/yolo/MfxfM6.txt (deflated 37%)
#   adding: final_data/yolo/DaPZjF.txt (deflated 33%)
#   adding: final_data/yolo/lHJp7s.txt (deflated 47%)
#   adding: final_data/yolo/ZMdpxr.txt (deflated 32%)
#   adding: final_data/yolo/PeZTLh.txt (deflated 44%)
#   adding: final_data/yolo/jJqERI.txt (deflated 37%)
#   adding: final_data/yolo/uPYxax.txt (deflated 40%)
#   adding: final_data/yolo/tpQk77.txt (deflated 45%)
#   adding: final_data/yolo/igTnzd.txt (deflated 45%)
#   adding: final_data/yolo/NwczQq.txt (deflated 34%)
#   adding: final_data/yolo/kybtym.txt (deflated 42%)
#   adding: final_data/yolo/kJIFgD.txt (deflated 38%)
#   adding: final_data/yolo/Zc22Yc.txt (deflated 43%)
#   adding: final_data/yolo/wUQT9h.txt (deflated 49%)
#   adding: final_data/yolo/F2fB4E.txt (deflated 42%)
#   adding: final_data/yolo/RM0BEK.txt (deflated 44%)
#   adding: final_data/yolo/Nryxy3.txt (deflated 26%)
#   adding: final_data/yolo/Oe9NvG.txt (deflated 36%)
#   adding: final_data/yolo/o9rUZd.txt (deflated 47%)
#   adding: final_data/yolo/fiYQdU.txt (deflated 43%)
#   adding: final_data/yolo/ZAatmV.txt (deflated 42%)
#   adding: final_data/yolo/Ir989x.txt (deflated 49%)
#   adding: final_data/yolo/cUmCGM.txt (deflated 43%)
#   adding: final_data/yolo/amVteX.txt (deflated 36%)
#   adding: final_data/yolo/YeMaTn.txt (deflated 42%)
#   adding: final_data/yolo/NAbOeY.txt (deflated 43%)
#   adding: final_data/yolo/2fydGQ.txt (deflated 40%)
#   adding: final_data/yolo/7DODMK.txt (deflated 44%)
#   adding: final_data/yolo/cOVIqr.txt (deflated 37%)
#   adding: final_data/yolo/7lYzzr.txt (deflated 36%)
#   adding: final_data/yolo/K4mIet.txt (deflated 37%)
#   adding: final_data/yolo/rTx3fm.txt (deflated 38%)
#   adding: final_data/yolo/zkanmD.txt (deflated 33%)
#   adding: final_data/yolo/AzMU6x.txt (deflated 45%)
#   adding: final_data/yolo/Gpr9NF.txt (deflated 35%)
#   adding: final_data/yolo/kSN8Uy.txt (deflated 42%)
#   adding: final_data/yolo/Hgsn6w.txt (deflated 40%)
#   adding: final_data/yolo/1wxoAv.txt (deflated 40%)
#   adding: final_data/yolo/jcxoIy.txt (deflated 34%)
#   adding: final_data/yolo/ruQKZf.txt (deflated 33%)
#   adding: final_data/yolo/m0WyYq.txt (deflated 34%)
#   adding: final_data/yolo/W4IW3H.txt (deflated 46%)
#   adding: final_data/yolo/tBBIrR.txt (deflated 32%)
#   adding: final_data/yolo/EbOCny.txt (deflated 45%)
#   adding: final_data/yolo/Nt3xSq.txt (deflated 50%)
#   adding: final_data/yolo/G0QWkT.txt (deflated 33%)
#   adding: final_data/yolo/W96IH9.txt (deflated 43%)
#   adding: final_data/yolo/Yx90iR.txt (deflated 34%)
#   adding: final_data/yolo/TdwHrf.txt (deflated 37%)
#   adding: final_data/yolo/0lc0Xu.txt (deflated 38%)
#   adding: final_data/yolo/FBRNYF.txt (deflated 40%)
#   adding: final_data/yolo/3NSzon.txt (deflated 51%)
#   adding: final_data/yolo/srH3bK.txt (deflated 28%)
#   adding: final_data/yolo/5tWcza.txt (deflated 40%)
#   adding: final_data/yolo/jPOpsi.txt (deflated 51%)
#   adding: final_data/yolo/nWDj6I.txt (deflated 29%)
#   adding: final_data/yolo/bSNb9h.txt (deflated 40%)
#   adding: final_data/yolo/gTnA7C.txt (deflated 43%)
#   adding: final_data/yolo/M9TC8K.txt (deflated 35%)
#   adding: final_data/yolo/gcFtt4.txt (deflated 38%)
#   adding: final_data/yolo/MaO0VC.txt (deflated 31%)
#   adding: final_data/yolo/I9Xavc.txt (deflated 40%)
#   adding: final_data/yolo/OIRXP2.txt (deflated 53%)
#   adding: final_data/yolo/iQUYcI.txt (deflated 45%)
#   adding: final_data/yolo/5FlyIU.txt (deflated 49%)
#   adding: final_data/yolo/ifYnsa.txt (deflated 32%)
#   adding: final_data/yolo/Jb7n0T.txt (deflated 36%)
#   adding: final_data/yolo/SQwnXI.txt (deflated 31%)
#   adding: final_data/yolo/kJZXFu.txt (deflated 42%)
#   adding: final_data/yolo/YC6VAo.txt (deflated 33%)
#   adding: final_data/yolo/iRAgUw.txt (deflated 40%)
#   adding: final_data/yolo/jygH8w.txt (deflated 29%)
#   adding: final_data/yolo/CpmvE6.txt (deflated 42%)
#   adding: final_data/yolo/VInjuI.txt (deflated 48%)
#   adding: final_data/yolo/cYZoit.txt (deflated 42%)
#   adding: final_data/yolo/Ef4BfM.txt (deflated 43%)
#   adding: final_data/yolo/u4NnAJ.txt (deflated 39%)
#   adding: final_data/yolo/XtkXYn.txt (deflated 40%)
#   adding: final_data/yolo/fprupX.txt (deflated 39%)
#   adding: final_data/yolo/K16qHX.txt (deflated 38%)
#   adding: final_data/yolo/XwmRz9.txt (deflated 40%)
#   adding: final_data/yolo/NzU3fK.txt (deflated 53%)
#   adding: final_data/yolo/T8PM03.txt (deflated 32%)
#   adding: final_data/yolo/liGCKs.txt (deflated 46%)
#   adding: final_data/yolo/HRN2zx.txt (deflated 33%)
#   adding: final_data/yolo/vk3pcq.txt (deflated 40%)
#   adding: final_data/yolo/3hPdCz.txt (deflated 37%)
#   adding: final_data/yolo/eSKbcP.txt (deflated 43%)
#   adding: final_data/yolo/PVV4Vc.txt (deflated 46%)
#   adding: final_data/yolo/6ofcgs.txt (deflated 47%)
#   adding: final_data/yolo/YIpqfv.txt (deflated 52%)
#   adding: final_data/yolo/U1aGLB.txt (deflated 37%)
#   adding: final_data/yolo/aSFxye.txt (deflated 36%)
#   adding: final_data/yolo/SBGnbo.txt (deflated 43%)
#   adding: final_data/yolo/5v3JCG.txt (deflated 43%)
#   adding: final_data/yolo/dTrIN9.txt (deflated 36%)
#   adding: final_data/yolo/hhboa8.txt (deflated 35%)
#   adding: final_data/yolo/LcbKHC.txt (deflated 35%)
#   adding: final_data/yolo/541igs.txt (deflated 26%)
#   adding: final_data/yolo/KIRhQf.txt (deflated 44%)
#   adding: final_data/yolo/9H6APl.txt (deflated 46%)
#   adding: final_data/yolo/LPokYI.txt (deflated 40%)
#   adding: final_data/yolo/ofiIFX.txt (deflated 41%)
#   adding: final_data/yolo/j4M6hM.txt (deflated 45%)
#   adding: final_data/yolo/0DZyRG.txt (deflated 45%)
#   adding: final_data/yolo/XhQVLZ.txt (deflated 35%)
#   adding: final_data/yolo/ObLZNV.txt (deflated 45%)
#   adding: final_data/yolo/BX6NfS.txt (deflated 38%)
#   adding: final_data/yolo/8p8oMn.txt (deflated 43%)
#   adding: final_data/yolo/QxhmKF.txt (deflated 43%)
#   adding: final_data/yolo/tHB9cc.txt (deflated 27%)
#   adding: final_data/yolo/rzeWL8.txt (deflated 40%)
#   adding: final_data/yolo/FGztt7.txt (deflated 37%)
#   adding: final_data/yolo/nTbROM.txt (deflated 38%)
#   adding: final_data/yolo/PPVbPQ.txt (deflated 45%)
#   adding: final_data/yolo/wzanBF.txt (deflated 40%)
#   adding: final_data/yolo/5uXmC0.txt (deflated 40%)
#   adding: final_data/yolo/S50fKP.txt (deflated 31%)
#   adding: final_data/yolo/xCtMbV.txt (deflated 37%)
#   adding: final_data/yolo/PeP9iw.txt (deflated 42%)
#   adding: final_data/yolo/XXCzEz.txt (deflated 55%)
#   adding: final_data/yolo/fvmIc9.txt (deflated 42%)
#   adding: final_data/yolo/59xs9t.txt (deflated 42%)
#   adding: final_data/yolo/Vlzy0L.txt (deflated 32%)
#   adding: final_data/yolo/qR5U6K.txt (deflated 32%)
#   adding: final_data/yolo/LVtlkz.txt (deflated 38%)
#   adding: final_data/yolo/3umoWR.txt (deflated 60%)
#   adding: final_data/yolo/KQMW77.txt (deflated 46%)
#   adding: final_data/yolo/wcsBq2.txt (deflated 46%)
#   adding: final_data/yolo/yzjeXw.txt (deflated 45%)
#   adding: final_data/yolo/FC8rNm.txt (deflated 32%)
#   adding: final_data/yolo/AjZ9Ju.txt (deflated 38%)
#   adding: final_data/yolo/dooN5H.txt (deflated 32%)
#   adding: final_data/yolo/moNRlR.txt (deflated 37%)
#   adding: final_data/yolo/Ss2V4z.txt (deflated 51%)
#   adding: final_data/yolo/UxecP6.txt (deflated 48%)
#   adding: final_data/yolo/9w7CHX.txt (deflated 42%)
#   adding: final_data/yolo/2uoZKP.txt (deflated 44%)
#   adding: final_data/yolo/ED3lqS.txt (deflated 45%)
#   adding: final_data/yolo/h17NzL.txt (deflated 47%)
#   adding: final_data/yolo/rPNPrF.txt (deflated 38%)
#   adding: final_data/yolo/Mk2jeH.txt (deflated 32%)
#   adding: final_data/yolo/bz89UO.txt (deflated 38%)
#   adding: final_data/yolo/DqeWi6.txt (deflated 47%)
#   adding: final_data/yolo/nWrAwh.txt (deflated 51%)
#   adding: final_data/yolo/eYKz6V.txt (deflated 42%)
#   adding: final_data/yolo/7aTrtY.txt (deflated 35%)
#   adding: final_data/yolo/a6nAkQ.txt (deflated 46%)
#   adding: final_data/yolo/BGEORx.txt (deflated 47%)
#   adding: final_data/yolo/9irmQx.txt (deflated 40%)
#   adding: final_data/yolo/cmGi8j.txt (deflated 45%)
#   adding: final_data/yolo/lKOC90.txt (deflated 36%)
#   adding: final_data/yolo/2zkJl6.txt (deflated 47%)
#   adding: final_data/yolo/VNSp3I.txt (deflated 42%)
#   adding: final_data/yolo/Azrl5U.txt (deflated 31%)
#   adding: final_data/yolo/OhpkOh.txt (deflated 42%)
#   adding: final_data/yolo/WWKPX7.txt (deflated 43%)
#   adding: final_data/yolo/Qofdn1.txt (deflated 36%)
#   adding: final_data/yolo/xTPo6w.txt (deflated 45%)
#   adding: final_data/yolo/ysWhSa.txt (deflated 45%)
#   adding: final_data/yolo/1oGr8m.txt (deflated 42%)
#   adding: final_data/yolo/Lpo6Bx.txt (deflated 37%)
#   adding: final_data/yolo/jf2Fs8.txt (deflated 46%)
#   adding: final_data/yolo/hADIfj.txt (deflated 34%)
#   adding: final_data/yolo/4O9pqv.txt (deflated 36%)
#   adding: final_data/yolo/VT6UTG.txt (deflated 43%)
#   adding: final_data/yolo/quhy85.txt (deflated 38%)
#   adding: final_data/yolo/EMpwPO.txt (deflated 40%)
#   adding: final_data/yolo/nd3NRn.txt (deflated 36%)
#   adding: final_data/yolo/qDVLMp.txt (deflated 42%)
#   adding: final_data/yolo/N0xvXt.txt (deflated 40%)
#   adding: final_data/yolo/aWT1CZ.txt (deflated 43%)
#   adding: final_data/yolo/JRrgnQ.txt (deflated 45%)
#   adding: final_data/yolo/7aLjon.txt (deflated 38%)
#   adding: final_data/yolo/JPEh9A.txt (deflated 37%)
#   adding: final_data/yolo/eyN5pU.txt (deflated 42%)
#   adding: final_data/yolo/FRF6Dt.txt (deflated 45%)
#   adding: final_data/yolo/s6iLZ0.txt (deflated 44%)
#   adding: final_data/yolo/GYUuZ1.txt (deflated 43%)
#   adding: final_data/yolo/TjnkEf.txt (deflated 34%)
#   adding: final_data/yolo/oDS3vJ.txt (deflated 40%)
#   adding: final_data/yolo/Uuv4SW.txt (deflated 37%)
#   adding: final_data/yolo/LtIaAG.txt (deflated 37%)
#   adding: final_data/yolo/1MpJqz.txt (deflated 46%)
#   adding: final_data/yolo/fJ7KnD.txt (deflated 29%)
#   adding: final_data/yolo/DOePkX.txt (deflated 32%)
#   adding: final_data/yolo/K4HpFp.txt (deflated 32%)
#   adding: final_data/yolo/E5EeII.txt (deflated 40%)
#   adding: final_data/yolo/wxW8ao.txt (deflated 51%)
#   adding: final_data/yolo/Hc2qjw.txt (deflated 43%)
#   adding: final_data/yolo/74fG8f.txt (deflated 44%)
#   adding: final_data/yolo/YtBI4H.txt (deflated 29%)
#   adding: final_data/yolo/QmNqZP.txt (deflated 40%)
#   adding: final_data/yolo/Egfmor.txt (deflated 71%)
#   adding: final_data/yolo/tm3LAH.txt (deflated 52%)
#   adding: final_data/yolo/iyihDB.txt (deflated 31%)
#   adding: final_data/yolo/urVWBd.txt (deflated 43%)
#   adding: final_data/yolo/xxt1Ns.txt (deflated 36%)
#   adding: final_data/yolo/tSIGLm.txt (deflated 40%)
#   adding: final_data/yolo/UycT5f.txt (deflated 36%)
#   adding: final_data/yolo/qv95dS.txt (deflated 45%)
#   adding: final_data/yolo/luUcqn.txt (deflated 47%)
#   adding: final_data/yolo/TQwzSw.txt (deflated 40%)
#   adding: final_data/yolo/hUx4uY.txt (deflated 48%)
#   adding: final_data/yolo/Wdd8P7.txt (deflated 42%)
#   adding: final_data/yolo/uU9dAY.txt (deflated 49%)
#   adding: final_data/yolo/DyV3HL.txt (deflated 43%)
#   adding: final_data/yolo/vBwYR2.txt (deflated 51%)
#   adding: final_data/yolo/Z9oJkc.txt (deflated 36%)
#   adding: final_data/yolo/3iUi1j.txt (deflated 34%)
#   adding: final_data/yolo/An9wHt.txt (deflated 38%)
#   adding: final_data/yolo/Cp4UJH.txt (deflated 38%)
#   adding: final_data/yolo/SXGSTG.txt (deflated 42%)
#   adding: final_data/yolo/HxDuw5.txt (deflated 44%)
#   adding: final_data/yolo/LlUuEs.txt (deflated 38%)
#   adding: final_data/yolo/m4LvvC.txt (deflated 41%)
#   adding: final_data/yolo/Sz78Sx.txt (deflated 42%)
#   adding: final_data/yolo/qbpua7.txt (deflated 33%)
#   adding: final_data/yolo/Sjh3NL.txt (deflated 37%)
#   adding: final_data/yolo/kafhq1.txt (deflated 40%)
#   adding: final_data/yolo/XhBmA6.txt (deflated 34%)
#   adding: final_data/yolo/FUvZZH.txt (deflated 40%)
#   adding: final_data/yolo/xhzT6M.txt (deflated 45%)
#   adding: final_data/yolo/dVEhEg.txt (deflated 43%)
#   adding: final_data/yolo/pUFtmp.txt (deflated 46%)
#   adding: final_data/yolo/FF5dSZ.txt (deflated 32%)
#   adding: final_data/yolo/NEFwwG.txt (deflated 40%)
#   adding: final_data/yolo/cSDtJQ.txt (deflated 41%)
#   adding: final_data/yolo/aAenys.txt (deflated 33%)
#   adding: final_data/yolo/k8S8fh.txt (deflated 43%)
#   adding: final_data/yolo/cobral.txt (deflated 42%)
#   adding: final_data/yolo/0Hdtoe.txt (deflated 26%)
#   adding: final_data/yolo/kvLGWE.txt (deflated 38%)
#   adding: final_data/yolo/N1bcaK.txt (deflated 46%)
#   adding: final_data/yolo/db0MJv.txt (deflated 56%)
#   adding: final_data/yolo/zZDXOU.txt (deflated 40%)
#   adding: final_data/yolo/vH4v9q.txt (deflated 35%)
#   adding: final_data/yolo/5svnk1.txt (deflated 38%)
#   adding: final_data/yolo/3fqDBT.txt (deflated 40%)
#   adding: final_data/yolo/oz393n.txt (deflated 60%)
#   adding: final_data/yolo/fYKbeY.txt (deflated 33%)
#   adding: final_data/yolo/LzMjCK.txt (deflated 30%)
#   adding: final_data/yolo/LeOBcf.txt (deflated 32%)
#   adding: final_data/yolo/TtrDC1.txt (deflated 45%)
#   adding: final_data/yolo/j4obke.txt (deflated 37%)
#   adding: final_data/yolo/s8KoGr.txt (deflated 40%)
#   adding: final_data/yolo/zRzBCD.txt (deflated 43%)
#   adding: final_data/yolo/Li3CMb.txt (deflated 43%)
#   adding: final_data/yolo/PVPKMt.txt (deflated 27%)
#   adding: final_data/yolo/9YTfl8.txt (deflated 38%)
#   adding: final_data/yolo/C1KigH.txt (deflated 34%)
#   adding: final_data/yolo/dEoHKF.txt (deflated 45%)
#   adding: final_data/yolo/FSgXcU.txt (deflated 34%)
#   adding: final_data/yolo/SKPiNG.txt (deflated 39%)
#   adding: final_data/yolo/7ympS3.txt (deflated 38%)
#   adding: final_data/yolo/zfaWR6.txt (deflated 43%)
#   adding: final_data/yolo/14knAr.txt (deflated 29%)
#   adding: final_data/yolo/PUomkn.txt (deflated 39%)
#   adding: final_data/yolo/EL0Cku.txt (deflated 40%)
#   adding: final_data/yolo/dKpgZz.txt (deflated 30%)
#   adding: final_data/yolo/BEjqOC.txt (deflated 37%)
#   adding: final_data/yolo/9SP0Km.txt (deflated 31%)
#   adding: final_data/yolo/OB94uX.txt (deflated 47%)
#   adding: final_data/images/ (stored 0%)
#   adding: final_data/images/NYi8FB.png (deflated 0%)
#   adding: final_data/images/bCvGel.png (deflated 0%)
#   adding: final_data/images/QxhmKF.png (deflated 0%)
#   adding: final_data/images/8FScev.png (deflated 7%)
#   adding: final_data/images/zCeBqm.png (deflated 0%)
#   adding: final_data/images/Nt3xSq.png (deflated 0%)
#   adding: final_data/images/AjZ9Ju.png (deflated 0%)
#   adding: final_data/images/k8S8fh.png (deflated 0%)
#   adding: final_data/images/Nryxy3.png (deflated 0%)
#   adding: final_data/images/An9wHt.png (deflated 0%)
#   adding: final_data/images/fvmIc9.png (deflated 0%)
#   adding: final_data/images/My2ZzY.png (deflated 0%)
#   adding: final_data/images/s14SEL.png (deflated 5%)
#   adding: final_data/images/s1GHot.png (deflated 0%)
#   adding: final_data/images/u6FC99.png (deflated 0%)
#   adding: final_data/images/2ttFs5.png (deflated 1%)
#   adding: final_data/images/SZkDf3.png (deflated 0%)
#   adding: final_data/images/LeOBcf.png (deflated 0%)
#   adding: final_data/images/U7oA4D.png (deflated 1%)
#   adding: final_data/images/hUx4uY.png (deflated 0%)
#   adding: final_data/images/KQMW77.png (deflated 17%)
#   adding: final_data/images/ur1zpS.png (deflated 0%)
#   adding: final_data/images/2EFHvT.png (deflated 0%)
#   adding: final_data/images/TQwzSw.png (deflated 0%)
#   adding: final_data/images/jPOpsi.png (deflated 0%)
#   adding: final_data/images/2qjnkx.png (deflated 1%)
#   adding: final_data/images/P9SCL7.png (deflated 0%)
#   adding: final_data/images/VFuVDd.png (deflated 0%)
#   adding: final_data/images/Oe9NvG.png (deflated 0%)
#   adding: final_data/images/ow140l.png (deflated 0%)
#   adding: final_data/images/1bc1JE.png (deflated 0%)
#   adding: final_data/images/G0QWkT.png (deflated 0%)
#   adding: final_data/images/9H6APl.png (deflated 0%)
#   adding: final_data/images/TlUgmq.png (deflated 0%)
#   adding: final_data/images/Z9oJkc.png (deflated 0%)
#   adding: final_data/images/xCtMbV.png (deflated 0%)
#   adding: final_data/images/5bxxLd.png (deflated 0%)
#   adding: final_data/images/SHYB7q.png (deflated 0%)
#   adding: final_data/images/WWKPX7.png (deflated 0%)
#   adding: final_data/images/jSPMmq.png (deflated 0%)
#   adding: final_data/images/nWDj6I.png (deflated 0%)
#   adding: final_data/images/9Xcy8m.png (deflated 0%)
#   adding: final_data/images/Ftn3kU.png (deflated 1%)
#   adding: final_data/images/WR19c4.png (deflated 0%)
#   adding: final_data/images/UxecP6.png (deflated 2%)
#   adding: final_data/images/QR80po.png (deflated 0%)
#   adding: final_data/images/9L7zbE.png (deflated 1%)
#   adding: final_data/images/zDBgLP.png (deflated 0%)
#   adding: final_data/images/kafhq1.png (deflated 0%)
#   adding: final_data/images/JpaFuW.png (deflated 0%)
#   adding: final_data/images/N7Jxv4.png (deflated 0%)
#   adding: final_data/images/FUvZZH.png (deflated 0%)
#   adding: final_data/images/EMpwPO.png (deflated 0%)
#   adding: final_data/images/kJIFgD.png (deflated 0%)
#   adding: final_data/images/bSNb9h.png (deflated 0%)
#   adding: final_data/images/6ofcgs.png (deflated 0%)
#   adding: final_data/images/KPzNIV.png (deflated 0%)
#   adding: final_data/images/hiBhzR.png (deflated 0%)
#   adding: final_data/images/5nhIQD.png (deflated 0%)
#   adding: final_data/images/eyN5pU.png (deflated 0%)
#   adding: final_data/images/FF5dSZ.png (deflated 0%)
#   adding: final_data/images/EZvlUE.png (deflated 0%)
#   adding: final_data/images/5v3JCG.png (deflated 0%)
#   adding: final_data/images/oAhbEX.png (deflated 0%)
#   adding: final_data/images/JTK8o5.png (deflated 1%)
#   adding: final_data/images/Vlzy0L.png (deflated 0%)
#   adding: final_data/images/5J4T7N.png (deflated 0%)
#   adding: final_data/images/4hzoQi.png (deflated 0%)
#   adding: final_data/images/Ss2V4z.png (deflated 0%)
#   adding: final_data/images/ps0pen.png (deflated 0%)
#   adding: final_data/images/w4yDrA.png (deflated 0%)
#   adding: final_data/images/yG2pzM.png (deflated 0%)
#   adding: final_data/images/zRzBCD.png (deflated 0%)
#   adding: final_data/images/eYKz6V.png (deflated 1%)
#   adding: final_data/images/UycT5f.png (deflated 0%)
#   adding: final_data/images/OhpkOh.png (deflated 0%)
#   adding: final_data/images/WXfTlS.png (deflated 0%)
#   adding: final_data/images/eF6CJk.png (deflated 0%)
#   adding: final_data/images/VNSp3I.png (deflated 0%)
#   adding: final_data/images/nKJoba.png (deflated 0%)
#   adding: final_data/images/K4mIet.png (deflated 0%)
#   adding: final_data/images/wxW8ao.png (deflated 0%)
#   adding: final_data/images/7CsTwH.png (deflated 0%)
#   adding: final_data/images/5fW3dl.png (deflated 0%)
#   adding: final_data/images/PaesbE.png (deflated 9%)
#   adding: final_data/images/4O9pqv.png (deflated 0%)
#   adding: final_data/images/uPYxax.png (deflated 0%)
#   adding: final_data/images/l3wBkM.png (deflated 0%)
#   adding: final_data/images/XhQVLZ.png (deflated 0%)
#   adding: final_data/images/8p8oMn.png (deflated 0%)
#   adding: final_data/images/fJ7KnD.png (deflated 1%)
#   adding: final_data/images/Z2oI2f.png (deflated 0%)
#   adding: final_data/images/H70Byr.png (deflated 0%)
#   adding: final_data/images/1yup5t.png (deflated 0%)
#   adding: final_data/images/devjb8.png (deflated 0%)
#   adding: final_data/images/wM1UTm.png (deflated 1%)
#   adding: final_data/images/g5Kccj.png (deflated 0%)
#   adding: final_data/images/sJwcA7.png (deflated 0%)
#   adding: final_data/images/ruQKZf.png (deflated 0%)
#   adding: final_data/images/GZaX0X.png (deflated 0%)
#   adding: final_data/images/QmNqZP.png (deflated 0%)
#   adding: final_data/images/59xs9t.png (deflated 0%)
#   adding: final_data/images/Jb7n0T.png (deflated 0%)
#   adding: final_data/images/yewB79.png (deflated 0%)
#   adding: final_data/images/5FlyIU.png (deflated 0%)
#   adding: final_data/images/rPNPrF.png (deflated 0%)
#   adding: final_data/images/S50fKP.png (deflated 0%)
#   adding: final_data/images/IwdAvd.png (deflated 24%)
#   adding: final_data/images/4GxaZ4.png (deflated 0%)
#   adding: final_data/images/TjnkEf.png (deflated 0%)
#   adding: final_data/images/1MpJqz.png (deflated 0%)
#   adding: final_data/images/SZHJsn.png (deflated 4%)
#   adding: final_data/images/3S8Ki0.png (deflated 2%)
#   adding: final_data/images/eSKbcP.png (deflated 1%)
#   adding: final_data/images/E7okPu.png (deflated 0%)
#   adding: final_data/images/vfYdiB.png (deflated 0%)
#   adding: final_data/images/db0MJv.png (deflated 1%)
#   adding: final_data/images/o9dI4s.png (deflated 0%)
#   adding: final_data/images/V7RF9T.png (deflated 5%)
#   adding: final_data/images/rFS2Pl.png (deflated 0%)
#   adding: final_data/images/635hxC.png (deflated 1%)
#   adding: final_data/images/YtBI4H.png (deflated 0%)
#   adding: final_data/images/Lpo6Bx.png (deflated 2%)
#   adding: final_data/images/7ympS3.png (deflated 0%)
#   adding: final_data/images/PeZTLh.png (deflated 0%)
#   adding: final_data/images/W96IH9.png (deflated 2%)
#   adding: final_data/images/AAQZsy.png (deflated 0%)
#   adding: final_data/images/xWHzRo.png (deflated 0%)
#   adding: final_data/images/Z68291.png (deflated 1%)
#   adding: final_data/images/FkHGnV.png (deflated 0%)
#   adding: final_data/images/1oGr8m.png (deflated 17%)
#   adding: final_data/images/vVIKIN.png (deflated 0%)
#   adding: final_data/images/bZPF8w.png (deflated 0%)
#   adding: final_data/images/I9Xavc.png (deflated 0%)
#   adding: final_data/images/2fydGQ.png (deflated 2%)
#   adding: final_data/images/xhzT6M.png (deflated 0%)
#   adding: final_data/images/PQYgDa.png (deflated 0%)
#   adding: final_data/images/liGCKs.png (deflated 22%)
#   adding: final_data/images/xxt1Ns.png (deflated 0%)
#   adding: final_data/images/Akg4LX.png (deflated 0%)
#   adding: final_data/images/sCh9SP.png (deflated 0%)
#   adding: final_data/images/Jtcb5I.png (deflated 0%)
#   adding: final_data/images/3VOUJU.png (deflated 0%)
#   adding: final_data/images/qbpua7.png (deflated 1%)
#   adding: final_data/images/Dz9kje.png (deflated 0%)
#   adding: final_data/images/HgfsDy.png (deflated 4%)
#   adding: final_data/images/LcozN2.png (deflated 0%)
#   adding: final_data/images/Hgsn6w.png (deflated 0%)
#   adding: final_data/images/Ybp3Zi.png (deflated 0%)
#   adding: final_data/images/jJqERI.png (deflated 0%)
#   adding: final_data/images/vBwYR2.png (deflated 0%)
#   adding: final_data/images/fYKbeY.png (deflated 0%)
#   adding: final_data/images/lEQvj6.png (deflated 0%)
#   adding: final_data/images/RRwyEd.png (deflated 0%)
#   adding: final_data/images/9irmQx.png (deflated 0%)
#   adding: final_data/images/Yx90iR.png (deflated 0%)
#   adding: final_data/images/3fqDBT.png (deflated 0%)
#   adding: final_data/images/LEvTcZ.png (deflated 0%)
#   adding: final_data/images/2zkJl6.png (deflated 1%)
#   adding: final_data/images/tBBIrR.png (deflated 0%)
#   adding: final_data/images/RHPPYo.png (deflated 0%)
#   adding: final_data/images/rYuSAe.png (deflated 22%)
#   adding: final_data/images/s6iLZ0.png (deflated 0%)
#   adding: final_data/images/HRN2zx.png (deflated 0%)
#   adding: final_data/images/aSFxye.png (deflated 0%)
#   adding: final_data/images/xri621.png (deflated 0%)
#   adding: final_data/images/CpmvE6.png (deflated 0%)
#   adding: final_data/images/N0xvXt.png (deflated 0%)
#   adding: final_data/images/WKyyEq.png (deflated 0%)
#   adding: final_data/images/oz393n.png (deflated 0%)
#   adding: final_data/images/cYZoit.png (deflated 0%)
#   adding: final_data/images/jzadhr.png (deflated 0%)
#   adding: final_data/images/igTnzd.png (deflated 0%)
#   adding: final_data/images/2OZFNQ.png (deflated 0%)
#   adding: final_data/images/PVV4Vc.png (deflated 0%)
#   adding: final_data/images/Gpr9NF.png (deflated 0%)
#   adding: final_data/images/lHJp7s.png (deflated 0%)
#   adding: final_data/images/jf2Fs8.png (deflated 0%)
#   adding: final_data/images/E5EeII.png (deflated 1%)
#   adding: final_data/images/7qS2c6.png (deflated 0%)
#   adding: final_data/images/h17NzL.png (deflated 1%)
#   adding: final_data/images/AzMU6x.png (deflated 0%)
#   adding: final_data/images/dKpgZz.png (deflated 1%)
#   adding: final_data/images/elp3OO.png (deflated 1%)
#   adding: final_data/images/VxUUWs.png (deflated 1%)
#   adding: final_data/images/m0WyYq.png (deflated 0%)
#   adding: final_data/images/srH3bK.png (deflated 0%)
#   adding: final_data/images/FnWrhr.png (deflated 0%)
#   adding: final_data/images/BX6NfS.png (deflated 1%)
#   adding: final_data/images/tSIGLm.png (deflated 0%)
#   adding: final_data/images/7DODMK.png (deflated 1%)
#   adding: final_data/images/tHB9cc.png (deflated 0%)
#   adding: final_data/images/xTPo6w.png (deflated 0%)
#   adding: final_data/images/TFyqeg.png (deflated 0%)
#   adding: final_data/images/74fG8f.png (deflated 0%)
#   adding: final_data/images/MhUUFc.png (deflated 0%)
#   adding: final_data/images/Sp8T3N.png (deflated 7%)
#   adding: final_data/images/LzMjCK.png (deflated 0%)
#   adding: final_data/images/0vrDd3.png (deflated 5%)
#   adding: final_data/images/NzU3fK.png (deflated 0%)
#   adding: final_data/images/WOFr38.png (deflated 0%)
#   adding: final_data/images/rzeWL8.png (deflated 0%)
#   adding: final_data/images/bzhb3V.png (deflated 0%)
#   adding: final_data/images/iRAgUw.png (deflated 0%)
#   adding: final_data/images/jIVj2q.png (deflated 0%)
#   adding: final_data/images/1wxoAv.png (deflated 1%)
#   adding: final_data/images/uermgn.png (deflated 0%)
#   adding: final_data/images/U1aGLB.png (deflated 0%)
#   adding: final_data/images/Uuv4SW.png (deflated 0%)
#   adding: final_data/images/94AV36.png (deflated 0%)
#   adding: final_data/images/Oqfy4Q.png (deflated 1%)
#   adding: final_data/images/PS8VO9.png (deflated 0%)
#   adding: final_data/images/hPwsmN.png (deflated 0%)
#   adding: final_data/images/yLTQsz.png (deflated 0%)
#   adding: final_data/images/MAFWtO.png (deflated 0%)
#   adding: final_data/images/l8xlgx.png (deflated 1%)
#   adding: final_data/images/iqoknG.png (deflated 0%)
#   adding: final_data/images/7gMyYO.png (deflated 6%)
#   adding: final_data/images/Sjh3NL.png (deflated 0%)
#   adding: final_data/images/oAozrp.png (deflated 0%)
#   adding: final_data/images/T8PM03.png (deflated 0%)
#   adding: final_data/images/TYhhZi.png (deflated 0%)
#   adding: final_data/images/DfpU0H.png (deflated 0%)
#   adding: final_data/images/mNvlOr.png (deflated 0%)
#   adding: final_data/images/m4LvvC.png (deflated 0%)
#   adding: final_data/images/H9uhwR.png (deflated 0%)
#   adding: final_data/images/fiYQdU.png (deflated 9%)
#   adding: final_data/images/kybtym.png (deflated 0%)
#   adding: final_data/images/F2fB4E.png (deflated 0%)
#   adding: final_data/images/eLzcMk.png (deflated 0%)
#   adding: final_data/images/IXUOye.png (deflated 0%)
#   adding: final_data/images/Kzf6bG.png (deflated 0%)
#   adding: final_data/images/g0W1Qc.png (deflated 0%)
#   adding: final_data/images/Gow60O.png (deflated 1%)
#   adding: final_data/images/qDVLMp.png (deflated 0%)
#   adding: final_data/images/hhboa8.png (deflated 2%)
#   adding: final_data/images/Mk2jeH.png (deflated 0%)
#   adding: final_data/images/6vgQg0.png (deflated 0%)
#   adding: final_data/images/1jNDT0.png (deflated 0%)
#   adding: final_data/images/dSFeVN.png (deflated 0%)
#   adding: final_data/images/dshKbW.png (deflated 0%)
#   adding: final_data/images/uVc2DK.png (deflated 0%)
#   adding: final_data/images/xnpPnK.png (deflated 1%)
#   adding: final_data/images/oDS3vJ.png (deflated 13%)
#   adding: final_data/images/dVEhEg.png (deflated 0%)
#   adding: final_data/images/tds2AM.png (deflated 0%)
#   adding: final_data/images/EL0Cku.png (deflated 0%)
#   adding: final_data/images/N6goUh.png (deflated 0%)
#   adding: final_data/images/YIpqfv.png (deflated 0%)
#   adding: final_data/images/LVtlkz.png (deflated 0%)
#   adding: final_data/images/vHShUq.png (deflated 0%)
#   adding: final_data/images/Pnsyl4.png (deflated 0%)
#   adding: final_data/images/dooN5H.png (deflated 1%)
#   adding: final_data/images/UbFGnp.png (deflated 0%)
#   adding: final_data/images/eIyHNR.png (deflated 0%)
#   adding: final_data/images/Azrl5U.png (deflated 0%)
#   adding: final_data/images/UOV7h2.png (deflated 0%)
#   adding: final_data/images/LlUuEs.png (deflated 19%)
#   adding: final_data/images/Kcer25.png (deflated 0%)
#   adding: final_data/images/QCWsnv.png (deflated 0%)
#   adding: final_data/images/FC8rNm.png (deflated 0%)
#   adding: final_data/images/W5CTpj.png (deflated 0%)
#   adding: final_data/images/tm3LAH.png (deflated 0%)
#   adding: final_data/images/ZMdpxr.png (deflated 0%)
#   adding: final_data/images/pbtm9v.png (deflated 1%)
#   adding: final_data/images/yTtG6x.png (deflated 0%)
#   adding: final_data/images/jygH8w.png (deflated 0%)
#   adding: final_data/images/vWgrNt.png (deflated 0%)
#   adding: final_data/images/0DZyRG.png (deflated 0%)
#   adding: final_data/images/Hc2qjw.png (deflated 0%)
#   adding: final_data/images/LT7rPq.png (deflated 0%)
#   adding: final_data/images/K4HpFp.png (deflated 0%)
#   adding: final_data/images/phKQW4.png (deflated 0%)
#   adding: final_data/images/XFV7ia.png (deflated 0%)
#   adding: final_data/images/49VNCb.png (deflated 0%)
#   adding: final_data/images/EA4Szk.png (deflated 1%)
#   adding: final_data/images/MefaJp.png (deflated 0%)
#   adding: final_data/images/EEyPaI.png (deflated 0%)
#   adding: final_data/images/9YTfl8.png (deflated 0%)
#   adding: final_data/images/urVWBd.png (deflated 1%)
#   adding: final_data/images/LcbKHC.png (deflated 0%)
#   adding: final_data/images/XtkXYn.png (deflated 0%)
#   adding: final_data/images/Zc22Yc.png (deflated 0%)
#   adding: final_data/images/amVteX.png (deflated 0%)
#   adding: final_data/images/5svnk1.png (deflated 0%)
#   adding: final_data/images/XXCzEz.png (deflated 30%)
#   adding: final_data/images/BT37On.png (deflated 0%)
#   adding: final_data/images/ggu3D6.png (deflated 0%)
#   adding: final_data/images/wzanBF.png (deflated 0%)
#   adding: final_data/images/nPvToI.png (deflated 0%)
#   adding: final_data/images/PVPKMt.png (deflated 0%)
#   adding: final_data/images/ymvEDt.png (deflated 0%)
#   adding: final_data/images/HxDuw5.png (deflated 0%)
#   adding: final_data/images/4fyknx.png (deflated 0%)
#   adding: final_data/images/nd3NRn.png (deflated 0%)
#   adding: final_data/images/2QhALF.png (deflated 0%)
#   adding: final_data/images/9SP0Km.png (deflated 0%)
#   adding: final_data/images/0Hdtoe.png (deflated 0%)
#   adding: final_data/images/OIRXP2.png (deflated 1%)
#   adding: final_data/images/kvLGWE.png (deflated 0%)
#   adding: final_data/images/ENDtIt.png (deflated 0%)
#   adding: final_data/images/Li3CMb.png (deflated 1%)
#   adding: final_data/images/9DV5Ow.png (deflated 0%)
#   adding: final_data/images/fprupX.png (deflated 0%)
#   adding: final_data/images/NAbOeY.png (deflated 0%)
#   adding: final_data/images/sUQbCS.png (deflated 0%)
#   adding: final_data/images/NEFwwG.png (deflated 0%)
#   adding: final_data/images/ZAatmV.png (deflated 0%)
#   adding: final_data/images/RM0BEK.png (deflated 0%)
#   adding: final_data/images/3hPdCz.png (deflated 0%)
#   adding: final_data/images/JRrgnQ.png (deflated 0%)
#   adding: final_data/images/wbMFQu.png (deflated 0%)
#   adding: final_data/images/TtrDC1.png (deflated 0%)
#   adding: final_data/images/N1bcaK.png (deflated 0%)
#   adding: final_data/images/KVlPe1.png (deflated 0%)
#   adding: final_data/images/e6ySPb.png (deflated 0%)
#   adding: final_data/images/DaPZjF.png (deflated 0%)
#   adding: final_data/images/zkanmD.png (deflated 0%)
#   adding: final_data/images/C1eKxM.png (deflated 28%)
#   adding: final_data/images/LtIaAG.png (deflated 0%)
#   adding: final_data/images/oUpo0b.png (deflated 0%)
#   adding: final_data/images/pUFtmp.png (deflated 0%)
#   adding: final_data/images/XwmRz9.png (deflated 0%)
#   adding: final_data/images/kGubU1.png (deflated 0%)
#   adding: final_data/images/PeP9iw.png (deflated 0%)
#   adding: final_data/images/GSVhvM.png (deflated 0%)
#   adding: final_data/images/AnE1wW.png (deflated 2%)
#   adding: final_data/images/SKPiNG.png (deflated 1%)
#   adding: final_data/images/qR5U6K.png (deflated 0%)
#   adding: final_data/images/aWT1CZ.png (deflated 0%)
#   adding: final_data/images/lZFGl1.png (deflated 0%)
#   adding: final_data/images/rmQX3A.png (deflated 0%)
#   adding: final_data/images/hDttQl.png (deflated 0%)
#   adding: final_data/images/j4M6hM.png (deflated 0%)
#   adding: final_data/images/u4NnAJ.png (deflated 0%)
#   adding: final_data/images/pVlH8o.png (deflated 0%)
#   adding: final_data/images/NfoWRy.png (deflated 0%)
#   adding: final_data/images/KIRhQf.png (deflated 0%)
#   adding: final_data/images/wcsBq2.png (deflated 0%)
#   adding: final_data/images/vk3pcq.png (deflated 0%)
#   adding: final_data/images/2UpAhL.png (deflated 0%)
#   adding: final_data/images/D875mz.png (deflated 0%)
#   adding: final_data/images/14knAr.png (deflated 0%)
#   adding: final_data/images/5OF3jR.png (deflated 0%)
#   adding: final_data/images/LPokYI.png (deflated 0%)
#   adding: final_data/images/Egfmor.png (deflated 0%)
#   adding: final_data/images/8ud2cB.png (deflated 0%)
#   adding: final_data/images/TJ88mT.png (deflated 0%)
#   adding: final_data/images/SQwnXI.png (deflated 0%)
#   adding: final_data/images/eIkrgY.png (deflated 0%)
#   adding: final_data/images/s8KoGr.png (deflated 0%)
#   adding: final_data/images/nWrAwh.png (deflated 0%)
#   adding: final_data/images/cmGi8j.png (deflated 0%)
#   adding: final_data/images/3NBdBz.png (deflated 0%)
#   adding: final_data/images/YjC1jg.png (deflated 0%)
#   adding: final_data/images/JPEh9A.png (deflated 0%)
#   adding: final_data/images/moNRlR.png (deflated 1%)
#   adding: final_data/images/2uoZKP.png (deflated 0%)
#   adding: final_data/images/GumLrv.png (deflated 1%)
#   adding: final_data/images/jRIaFl.png (deflated 0%)
#   adding: final_data/images/2kxu20.png (deflated 0%)
#   adding: final_data/images/dEoHKF.png (deflated 7%)
#   adding: final_data/images/YRpKwV.png (deflated 0%)
#   adding: final_data/images/YeMaTn.png (deflated 0%)
#   adding: final_data/images/CJfNuj.png (deflated 0%)
#   adding: final_data/images/7lYzzr.png (deflated 0%)
#   adding: final_data/images/NwczQq.png (deflated 0%)
#   adding: final_data/images/cUmCGM.png (deflated 0%)
#   adding: final_data/images/PUomkn.png (deflated 0%)
#   adding: final_data/images/VInjuI.png (deflated 1%)
#   adding: final_data/images/af2QEl.png (deflated 0%)
#   adding: final_data/images/qv95dS.png (deflated 0%)
#   adding: final_data/images/3umoWR.png (deflated 0%)
#   adding: final_data/images/HOLHuO.png (deflated 0%)
#   adding: final_data/images/e6oFyb.png (deflated 2%)
#   adding: final_data/images/DOePkX.png (deflated 0%)
#   adding: final_data/images/qSGM5L.png (deflated 0%)
#   adding: final_data/images/1gEVOB.png (deflated 0%)
#   adding: final_data/images/Ef4BfM.png (deflated 0%)
#   adding: final_data/images/BGEORx.png (deflated 0%)
#   adding: final_data/images/EOcQKu.png (deflated 0%)
#   adding: final_data/images/lKOC90.png (deflated 0%)
#   adding: final_data/images/16hDUB.png (deflated 1%)
#   adding: final_data/images/TVUz2Y.png (deflated 0%)
#   adding: final_data/images/N4SiPc.png (deflated 0%)
#   adding: final_data/images/qYeMDt.png (deflated 18%)
#   adding: final_data/images/DyV3HL.png (deflated 11%)
#   adding: final_data/images/VyQPXn.png (deflated 0%)
#   adding: final_data/images/wgA9UU.png (deflated 0%)
#   adding: final_data/images/YC6VAo.png (deflated 0%)
#   adding: final_data/images/zfaWR6.png (deflated 0%)
#   adding: final_data/images/KOOx4W.png (deflated 0%)
#   adding: final_data/images/EbOCny.png (deflated 0%)
#   adding: final_data/images/WxorIF.png (deflated 0%)
#   adding: final_data/images/QNqLAq.png (deflated 0%)
#   adding: final_data/images/MYF0rm.png (deflated 0%)
#   adding: final_data/images/chTwht.png (deflated 0%)
#   adding: final_data/images/tNiGh1.png (deflated 0%)
#   adding: final_data/images/WdwS3l.png (deflated 1%)
#   adding: final_data/images/OwtA06.png (deflated 1%)
#   adding: final_data/images/onjyZ3.png (deflated 0%)
#   adding: final_data/images/ehMcf0.png (deflated 0%)
#   adding: final_data/images/cOVIqr.png (deflated 0%)
#   adding: final_data/images/tpQk77.png (deflated 2%)
#   adding: final_data/images/0dnHXr.png (deflated 1%)
#   adding: final_data/images/IedUfS.png (deflated 0%)
#   adding: final_data/images/gD5Z9E.png (deflated 0%)
#   adding: final_data/images/aeKTRl.png (deflated 0%)
#   adding: final_data/images/TIeUTf.png (deflated 0%)
#   adding: final_data/images/boikB0.png (deflated 0%)
#   adding: final_data/images/gcFtt4.png (deflated 0%)
#   adding: final_data/images/FP4YlI.png (deflated 0%)
#   adding: final_data/images/5cib6m.png (deflated 0%)
#   adding: final_data/images/pFfCrq.png (deflated 0%)
#   adding: final_data/images/PPVbPQ.png (deflated 14%)
#   adding: final_data/images/kJZXFu.png (deflated 1%)
#   adding: final_data/images/FSgXcU.png (deflated 0%)
#   adding: final_data/images/541igs.png (deflated 0%)
#   adding: final_data/images/n6gin8.png (deflated 1%)
#   adding: final_data/images/4IkYjp.png (deflated 0%)
#   adding: final_data/images/MaO0VC.png (deflated 0%)
#   adding: final_data/images/BzXnpL.png (deflated 0%)
#   adding: final_data/images/TdwHrf.png (deflated 0%)
#   adding: final_data/images/nTbROM.png (deflated 1%)
#   adding: final_data/images/Ir989x.png (deflated 0%)
#   adding: final_data/images/VGca8q.png (deflated 1%)
#   adding: final_data/images/FRF6Dt.png (deflated 1%)
#   adding: final_data/images/3NSzon.png (deflated 1%)
#   adding: final_data/images/EZLJdw.png (deflated 0%)
#   adding: final_data/images/Qofdn1.png (deflated 0%)
#   adding: final_data/images/hSmT3b.png (deflated 0%)
#   adding: final_data/images/QrCKE8.png (deflated 0%)
#   adding: final_data/images/cSDtJQ.png (deflated 0%)
#   adding: final_data/images/NnIL90.png (deflated 0%)
#   adding: final_data/images/uuJkdW.png (deflated 0%)
#   adding: final_data/images/SXGSTG.png (deflated 1%)
#   adding: final_data/images/7aLjon.png (deflated 1%)
#   adding: final_data/images/yMIkC6.png (deflated 0%)
#   adding: final_data/images/vH4v9q.png (deflated 1%)
#   adding: final_data/images/XhBmA6.png (deflated 0%)
#   adding: final_data/images/ObLZNV.png (deflated 0%)
#   adding: final_data/images/JTkZdL.png (deflated 0%)
#   adding: final_data/images/Cp4UJH.png (deflated 0%)
#   adding: final_data/images/KZfWl6.png (deflated 0%)
#   adding: final_data/images/jcxoIy.png (deflated 0%)
#   adding: final_data/images/5uXmC0.png (deflated 0%)
#   adding: final_data/images/7aTrtY.png (deflated 0%)
#   adding: final_data/images/N54M99.png (deflated 0%)
#   adding: final_data/images/hADIfj.png (deflated 0%)
#   adding: final_data/images/tL3iOD.png (deflated 0%)
#   adding: final_data/images/iyihDB.png (deflated 0%)
#   adding: final_data/images/EJlBXj.png (deflated 0%)
#   adding: final_data/images/BEjqOC.png (deflated 0%)
#   adding: final_data/images/dTrIN9.png (deflated 0%)
#   adding: final_data/images/GYUuZ1.png (deflated 0%)
#   adding: final_data/images/iQUYcI.png (deflated 0%)
#   adding: final_data/images/Z7ulx6.png (deflated 0%)
#   adding: final_data/images/bAnm6T.png (deflated 0%)
#   adding: final_data/images/L579qK.png (deflated 1%)
#   adding: final_data/images/9w7CHX.png (deflated 0%)
#   adding: final_data/images/Q2P4Mu.png (deflated 0%)
#   adding: final_data/images/VT6UTG.png (deflated 0%)
#   adding: final_data/images/ke6ur9.png (deflated 0%)
#   adding: final_data/images/Nvi9L1.png (deflated 4%)
#   adding: final_data/images/0lc0Xu.png (deflated 0%)
#   adding: final_data/images/Wdd8P7.png (deflated 0%)
#   adding: final_data/images/jihrvA.png (deflated 0%)
#   adding: final_data/images/kSN8Uy.png (deflated 0%)
#   adding: final_data/images/aAenys.png (deflated 0%)
#   adding: final_data/images/K16qHX.png (deflated 0%)
#   adding: final_data/images/ED3lqS.png (deflated 0%)
#   adding: final_data/images/SBGnbo.png (deflated 0%)
#   adding: final_data/images/DqeWi6.png (deflated 3%)
#   adding: final_data/images/qrDddi.png (deflated 3%)
#   adding: final_data/images/5OKsRj.png (deflated 0%)
#   adding: final_data/images/FBRNYF.png (deflated 1%)
#   adding: final_data/images/6pXvXS.png (deflated 0%)
#   adding: final_data/images/6vTgVO.png (deflated 0%)
#   adding: final_data/images/bz89UO.png (deflated 0%)
#   adding: final_data/images/cobral.png (deflated 0%)
#   adding: final_data/images/ZJ2MBt.png (deflated 0%)
#   adding: final_data/images/wUQT9h.png (deflated 0%)
#   adding: final_data/images/a6nAkQ.png (deflated 0%)
#   adding: final_data/images/yzjeXw.png (deflated 62%)
#   adding: final_data/images/OetKcL.png (deflated 0%)
#   adding: final_data/images/n8A3z9.png (deflated 0%)
#   adding: final_data/images/OB94uX.png (deflated 0%)
#   adding: final_data/images/rTx3fm.png (deflated 0%)
#   adding: final_data/images/OlXrRR.png (deflated 0%)
#   adding: final_data/images/o9rUZd.png (deflated 0%)
#   adding: final_data/images/MfxfM6.png (deflated 0%)
#   adding: final_data/images/ofiIFX.png (deflated 0%)
#   adding: final_data/images/jFWe66.png (deflated 0%)
#   adding: final_data/images/ZOguNK.png (deflated 0%)
#   adding: final_data/images/kuXwgY.png (deflated 0%)
#   adding: final_data/images/fg0O0S.png (deflated 1%)
#   adding: final_data/images/XF8KRX.png (deflated 0%)
#   adding: final_data/images/C1KigH.png (deflated 0%)
#   adding: final_data/images/z66Bn8.png (deflated 0%)
#   adding: final_data/images/oS3dpY.png (deflated 33%)
#   adding: final_data/images/FGztt7.png (deflated 28%)
#   adding: final_data/images/gTnA7C.png (deflated 0%)
#   adding: final_data/images/luUcqn.png (deflated 0%)
#   adding: final_data/images/NnFqC0.png (deflated 0%)
#   adding: final_data/images/3iUi1j.png (deflated 0%)
#   adding: final_data/images/hKIsbz.png (deflated 0%)
#   adding: final_data/images/j4obke.png (deflated 0%)
#   adding: final_data/images/W4IW3H.png (deflated 1%)
#   adding: final_data/images/quhy85.png (deflated 0%)
#   adding: final_data/images/ifYnsa.png (deflated 1%)
#   adding: final_data/images/zZDXOU.png (deflated 0%)
#   adding: final_data/images/xvdEEe.png (deflated 0%)
#   adding: final_data/images/uU9dAY.png (deflated 0%)
#   adding: final_data/images/CRJ1wL.png (deflated 0%)
#   adding: final_data/images/5tWcza.png (deflated 0%)
#   adding: final_data/images/PhZv5C.png (deflated 0%)
#   adding: final_data/images/FPm5Co.png (deflated 0%)
#   adding: final_data/images/ysWhSa.png (deflated 0%)
#   adding: final_data/images/aurnfm.png (deflated 1%)
#   adding: final_data/images/Sz78Sx.png (deflated 1%)
#   adding: final_data/images/M9TC8K.png (deflated 0%)
#   adding: final_data/images/3W3Dq5.png (deflated 10%)
#   adding: final_data/images/DW4xxJ.png (deflated 0%)
